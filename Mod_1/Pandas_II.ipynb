# %% [markdown]
# # Pandas II - Data Cleaning
#
# _May 13, 2020_
#
# Agenda today:
# - Introduction to lambda function
# - Introduction to data cleaning in pandas

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Part I. Lambda function
# lambda functions are known as anonymous functions in Python. It allows you to write one-line functions that are used together with `map()`, `filter()`.
#
# Syntax of lambda function: `lambda arguments:expressions`.

# %%
# lambda function with one argument
 
# take in an integer increment it by 10
func_1 = lambda x : x + 10

# %%
# using the function
func_1(10)
# Out:
# 20

# %%
# lambda function with multiple arguments
func_2 = lambda x,y,z: x + 10 + y + z
func_2(2,3,5)
# Out:
# 20

# %%
# exercise: turn the below function into a lambda function
def count_zeros(li):
    """
    return a count of how many zeros are in a list
    """
    count = sum(x == 0 for x in li)
    return count

# %%
count_zeros([1,2,4,0,0,0])

# %%
# solution 1 - hint, use map()
sum(list(map(lambda x: x == 0, [1,2,4,0,0,0])))
# Out:
# 3

# %%
# solution 2 - hint, use filter()
len(list(filter(lambda x: x == 0, [1,2,4,0,0,0])))
# Out:
# 3

# %% [markdown]
# ## Part II. Data Cleaning in Pandas
# You might wonder what the usage of lambda functions are - they are incredibly useful when applied to data cleaning in Pandas. You can apply it to columns or the entire dataframe to get results you need. For example, you might want to convert a column with $USD to Euros, or temperature expressed in Celsius to Fehrenheit. You will learn three new functions:
#
# - `Apply()` - on both series and dataframe
#
# - `Applymap()` - only on dataframes
#
# - `Map()` - only on series

# %%
# import the dataframe 
df = pd.read_csv('auto-mpg.csv')
df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
# examine the first few rows of it 
df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
# check the datatypes of the df
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   car name      398 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
# check the df of columns
df.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model year', 'origin', 'car name'],
#       dtype='object')

# %%
# check whether you have missing values
sum(df.isnull)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-853f8339d6fd> in <module>
#       1 # check whether you have missing values
# ----> 2 sum(df.isnull)
#
# TypeError: 'method' object is not iterable

# %%
# creating new columns - show the broadcasting property of pandas
df['usable?'] = 'Yes'
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name usable?
# 0            70       1  chevrolet chevelle malibu     Yes
# 1            70       1          buick skylark 320     Yes
# 2            70       1         plymouth satellite     Yes
# 3            70       1              amc rebel sst     Yes
# 4            70       1                ford torino     Yes
# ..          ...     ...                        ...     ...
# 393          82       1            ford mustang gl     Yes
# 394          82       2                  vw pickup     Yes
# 395          82       1              dodge rampage     Yes
# 396          82       1                ford ranger     Yes
# 397          82       1                 chevy s-10     Yes
#
# [398 rows x 10 columns]

# %%
# check the dataframe
#df['new_column'] = df.old_column_you_want_to_apply_things_to.apply(lambda functon)
df['new cylinders']=df.cylinders.apply(lambda x : x-1)
df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                   car name usable?  new cylinders
# 0       1  chevrolet chevelle malibu     Yes              7
# 1       1          buick skylark 320     Yes              7
# 2       1         plymouth satellite     Yes              7
# 3       1              amc rebel sst     Yes              7
# 4       1                ford torino     Yes              7

# %%
# time to use lambda and apply! with apply, applymap, and map, you never need to "iterate through the rows"

# create a new column called weight_in_tons, which uses `weight` column and multiply it by 0.0005

# 1 lb = 0.0005

df['weight_in_tons'] = df.weight.apply(lambda x : x * .0005)
df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                   car name usable?  new cylinders  weight_in_tons
# 0       1  chevrolet chevelle malibu     Yes              7          1.7520
# 1       1          buick skylark 320     Yes              7          1.8465
# 2       1         plymouth satellite     Yes              7          1.7180
# 3       1              amc rebel sst     Yes              7          1.7165
# 4       1                ford torino     Yes              7          1.7245

# %%
# exercise - create a new column called "years old", which determines how old a car is 

# if the car is modeled in`70`, it would be 50 years old 

df['years old'] = df['model year'].apply(lambda x : 120 - x)
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name usable?  new cylinders  \
# 0            70       1  chevrolet chevelle malibu     Yes              7
# 1            70       1          buick skylark 320     Yes              7
# 2            70       1         plymouth satellite     Yes              7
# 3            70       1              amc rebel sst     Yes              7
# 4            70       1                ford torino     Yes              7
# ..          ...     ...                        ...     ...            ...
# 393          82       1            ford mustang gl     Yes              3
# 394          82       2                  vw pickup     Yes              3
# 395          82       1              dodge rampage     Yes              3
# 396          82       1                ford ranger     Yes              3
# 397          82       1                 chevy s-10     Yes              3
#
#      weight_in_tons  years old
# 0            1.7520         50
# 1            1.8465         50
# 2            1.7180         50
# 3            1.7165         50
# 4            1.7245         50
# ..              ...        ...
# 393          1.3950         38
# 394          1.0650         38
# 395          1.1475         38
# 396          1.3125         38
# 397          1.3600         38
#
# [398 rows x 13 columns]

# %% [markdown]
# #### What's Next?
# - Pandas Groupby functions and aggregation
# - Combining multiple dataframes
